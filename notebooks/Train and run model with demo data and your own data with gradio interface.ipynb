# %%
from google.colab import userdata
import os


# !git clone https://github.com/FTF1990/Industrial-digital-twin-by-transformer.git

# %cd Industrial-digital-twin-by-transformer
# !pip install kaggle
# Out:
# Cloning into 'Industrial-digital-twin-by-transformer'...
# fatal: could not read Password for 'https://%7Btoken%7D@github.com': No such device or address
# [Errno 2] No such file or directory: 'Industrial-digital-twin-by-transformer'
# /content

# %%
#Make sure that you connected to T4 or A100 GPU(CPU env was not tested)
import torch
print(f"PyTorch版本: {torch.__version__}")
print(f"CUDA可用: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch版本: 2.8.0+cu126
# CUDA可用: True
# GPU: Tesla T4

# %%
# Download demo data from kaggle
import kagglehub

path = kagglehub.dataset_download("tianffan/power-gen-machine")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 159M/159M [00:00<00:00, 243MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/tianffan/power-gen-machine/versions/1

# %%
# copy demo data to project if Path to dataset files: /root/.cache/kagglehub/datasets/tianffan/power-gen-machine/versions/1
import os
os.makedirs('data', exist_ok=True)
# !cp /root/.cache/kagglehub/datasets/tianffan/power-gen-machine/versions/1/data.csv data/

# %%
# copy demo data to project if Path to dataset files:  /kaggle/input/
import os
os.makedirs('data', exist_ok=True)
# !cp /kaggle/input/power-gen-machine/data.csv data/
# Out:
# cp: cannot stat '/kaggle/input/power-gen-machine/data.csv': No such file or directory

# %%
#run and test with demo data in gradio app
# !python gradio_sensor_transformer_app.py
# Out:
# python3: can't open file '/content/gradio_residual_tft_app.py': [Errno 2] No such file or directory

# %% [markdown]
# If you need to try your own data, just copy your data to path: /content/Industrial-digital-twin-by-transformer/data.
# Note: pls keep your data same format as the demo data which is a very simple csv format.
